# %%
import pickle
import pandas as pd
import numpy as np

# %%
with open('/Users/zhangzhiwen/Documents/ERGO-master-test20/pep_test_result_ae2', 'rb') as file:
    data1 = pickle.load(file)

# %%
ls1=[]
for i in data1:
    ls1.append([i[0],i[2]])

# %%
ls1
# Out:
# [['MIELSLIDFY', 0.8106589743589744],
#  ['IDFYLCFLAF', 0.8334357426828601],
#  ['LLFLVLIML', 0.8131443246019519],
#  ['IELSLIDFYL', 0.8117565300742872],
#  ['FLAFLLFLV', 0.8209748628595441],
#  ['LIDFYLCFL', 0.8007112754679532],
#  ['FYLCFLAFLL', 0.8202469262971194],
#  ['AFLLFLVLI', 0.8273838517168938],
#  ['YLCFLAFLL', 0.7984001280901001],
#  ['FYLCFLAFL', 0.826222344697268],
#  ['SLIDFYLCFL', 0.8140426317625096],
#  ['HTTDPSFLGRY', 0.8075676638176639],
#  ['INVFAFPFTI', 0.8552849847163201],
#  ['YINVFAFPF', 0.8712941253807218],
#  ['NVFAFPFTIY', 0.8737395833333335],
#  ['FLWLLWPVTL', 0.7962104197299467],
#  ['AFPFTIYSL', 0.8641486768187119],
#  ['GYINVFAFPF', 0.8801379240403631],
#  ['MGYINVFAF', 0.8783545840922891],
#  ['NVFAFPFTI', 0.8745663594013282],
#  ['FVDGVPFVV', 0.6330985638402519],
#  ['FLWLLWPVT', 0.8031843267108167],
#  ['WPVTLACFVL', 0.7636116552831754],
#  ['WLLWPVTLA', 0.829953560371517],
#  ['LWPVTLACF', 0.8044784000528036],
#  ['TLACFVLAAV', 0.8155015615485848],
# ...

# %%
df_ae = pd.DataFrame(ls1,columns = ['pep','ae_auc'])

# %%
df_ae
# Out:
#             pep    ae_auc
# 0    MIELSLIDFY  0.810659
# 1    IDFYLCFLAF  0.833436
# 2     LLFLVLIML  0.813144
# 3    IELSLIDFYL  0.811757
# 4     FLAFLLFLV  0.820975
# ..          ...       ...
# 264  KTSVDCTMYI  0.509259
# 265  FCNDPFLGVY  0.561364
# 266   ALNTPKDHI  0.672727
# 267   ELIRQGTDY  0.921569
# 268  CTLKSFTVEK  0.812500
#
# [269 rows x 2 columns]

# %%
with open('/Users/zhangzhiwen/Documents/ERGO-master-test20/pep_test_result_lstm2', 'rb') as fi:
    data2 = pickle.load(fi)

# %%
ls2=[]
for i in data2:
    ls2.append([i[0],i[2]])

# %%
df_lstm = pd.DataFrame(ls2,columns = ['pep','lstm_auc'])

# %%
df_lstm
# Out:
#             pep  lstm_auc
# 0    MIELSLIDFY  0.810633
# 1    IDFYLCFLAF  0.815101
# 2     LLFLVLIML  0.812332
# 3    IELSLIDFYL  0.813459
# 4     FLAFLLFLV  0.837084
# ..          ...       ...
# 263  KTSVDCTMYI  0.632075
# 264  FCNDPFLGVY  0.583333
# 265   ALNTPKDHI  0.666667
# 266   ELIRQGTDY  0.980392
# 267  CTLKSFTVEK  0.666667
#
# [268 rows x 2 columns]

# %%
df_all = pd.merge(df_ae, df_lstm, on = 'pep')

# %%
df_all
# Out:
#             pep    ae_auc  lstm_auc
# 0    MIELSLIDFY  0.810659  0.810633
# 1    IDFYLCFLAF  0.833436  0.815101
# 2     LLFLVLIML  0.813144  0.812332
# 3    IELSLIDFYL  0.811757  0.813459
# 4     FLAFLLFLV  0.820975  0.837084
# ..          ...       ...       ...
# 262  KTSVDCTMYI  0.509259  0.632075
# 263  FCNDPFLGVY  0.561364  0.583333
# 264   ALNTPKDHI  0.672727  0.666667
# 265   ELIRQGTDY  0.921569  0.980392
# 266  CTLKSFTVEK  0.812500  0.666667
#
# [267 rows x 3 columns]

# %%
df_all['ae_auc']=df_all['ae_auc'].round(4)

# %%
df_all['lstm_auc']=df_all['lstm_auc'].round(4)

# %%
df_all.to_csv('ERGO20_singlepep.csv',index = False)

# %%
df_all

# %%
df10 = pd.read_csv('ERGO10_singlepep.csv')

# %%
df20 = pd.read_csv('ERGO20_singlepep.csv')

# %%
df_test = pd.merge(df10, df20, on = 'pep',how="outer")

# %%
df_test.to_csv('ERGO10and20.csv',index = False)

# %%
df_test
# Out:
#             pep  ae_auc_x  lstm_auc_x  ae_auc_y  lstm_auc_y
# 0     FYLCFLAFL    0.7260      0.7319    0.8262      0.8367
# 1    IDFYLCFLAF    0.7080      0.7293    0.8334      0.8151
# 2     LLFLVLIML    0.7304      0.7443    0.8131      0.8123
# 3     LIDFYLCFL    0.7451      0.7361    0.8007      0.8086
# 4    FYLCFLAFLL    0.7497      0.7518    0.8202      0.8396
# ..          ...       ...         ...       ...         ...
# 264  KTSVDCTMYI       NaN         NaN    0.5093      0.6321
# 265  FCNDPFLGVY       NaN         NaN    0.5614      0.5833
# 266   ALNTPKDHI       NaN         NaN    0.6727      0.6667
# 267   ELIRQGTDY       NaN         NaN    0.9216      0.9804
# 268  CTLKSFTVEK       NaN         NaN    0.8125      0.6667
#
# [269 rows x 5 columns]

# %%
data = np.load('/Users/zhangzhiwen/Documents/ERGO-master-test20/roc_ae.npz')

# %%
data.files

# %%
data['auc']

# %%
data_lstm = np.load('/Users/zhangzhiwen/Documents/ERGO-master-test20/roc_lstm.npz')

# %%
data_lstm['auc']

# %%
lstm_fpr=data_lstm['fpr']
lstm_tpr=data_lstm['tpr']
lstm_auc=data_lstm['auc']

# %%
ae_fpr=data['fpr']
ae_tpr=data['tpr']
ae_auc=data['auc']

# %%
import matplotlib.pyplot as plt

# %%
plt.figure
plt.title('roc')
plt.plot(lstm_fpr, lstm_tpr, 'b',label='LSTM embedding method, AUC:0.906')
plt.plot(ae_fpr, ae_tpr, 'y',label = 'AE embedding method, AUC:0.814')
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
