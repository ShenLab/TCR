# %%
import pandas as pd

# %%
df20all = pd.read_csv('/Users/zhangzhiwen/Desktop/ERGO-master/data20.csv')

# %%
df20allcount = df20all.groupby(['CDR3','TRBV_gene','TRBJ_gene','AA']).size().sort_values(ascending=False)

# %%
df20allcount = df20allcount.reset_index()
df20allcount.rename(columns={0: 'count'}, inplace=True)

# %%
df20allcount = df20all[['CDR3','AA']]

# %%
df20allcount = df10all

# %%
df20allcount_drop = df20allcount.drop(df20allcount[df20allcount.CDR3.str.contains(r'[@#&$%+-/*X]')].index)

# %%
df20allcount_drop

# %%
df20allcount_drop = df20allcount_drop.drop(df20allcount_drop[df20allcount_drop.AA.str.contains(r'[@#&$%+-/*X]')].index)

# %%
df20allcount_drop

# %%
df20allcount_drop = df20allcount_drop.drop(df20allcount_drop[df20allcount_drop.TRBV_gene.str.contains(r'[@#&%+*X]')
                                                            |df20allcount_drop.TRBJ_gene.str.contains(r'[@#&%+*X]')].index)

# %%
df20allcount_drop

# %%
df20allcount_drop = df20allcount_drop.sample(frac=1)

# %%
df20allcount_dropnew = df20allcount_drop[['CDR3','AA','count']]

# %%
test = df20allcount_dropnew[['CDR3','AA']]

# %%
test

# %%
test.drop_duplicates()

# %%
df20allcount_drop

# %%
df20allcount_drop.to_csv('deepTCR_compare_noVJ10.csv',index = False)

# %%
AA_list = list(set(df20allcount_drop['AA']))

# %%
len(AA_list)

# %%
import os

# %%
def tocsv(aalist,dataframe):
    for i in aalist:
        out = dataframe.loc[dataframe['AA'] == i]
        dirname=str(i)
        os.mkdir('/Users/zhangzhiwen/Documents/deepTCR_compare10_noVJ/{}'.format(dirname))
        filename=str(i)
        out[['CDR3','AA']].to_csv('/Users/zhangzhiwen/Documents/deepTCR_compare10_noVJ/{d}/{f}.tsv'.format(d=dirname,f=filename),sep='\t',index = None)

# %%
tocsv(AA_list,df20allcount_drop)

# %%
df20allcount_dropnew[df20allcount_dropnew['AA']=='GTTLPKGFY']

# %%
import DeepTCR

# %%
from DeepTCR.DeepTCR import DeepTCR_SS

# Instantiate training object
DTCR_SS = DeepTCR_SS('deepTCR_compare20_VJ')

#Load Data from directories
DTCR_SS.Get_Data(directory='/Users/zhangzhiwen/Documents/deepTCR_compare20_VJ',Load_Prev_Data=False,aggregate_by_aa=True,
               aa_column_beta=0,count_column=None,v_beta_column=1,j_beta_column=2)
# Out:
# Loading Data...
# Embedding Sequences...
# Data Loaded

# %%
DTCR_SS.Get_Train_Valid_Test(test_size=0.2)
DTCR_SS.Train()
# Out:
# WARNING:tensorflow:From /Users/zhangzhiwen/opt/anaconda3/lib/python3.7/site-packages/DeepTCR-1.4.19-py3.7.egg/DeepTCR/functions/Layers.py:130: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/zhangzhiwen/opt/anaconda3/lib/python3.7/site-packages/DeepTCR-1.4.19-py3.7.egg/DeepTCR/functions/Layers.py:135: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /Users/zhangzhiwen/opt/anaconda3/lib/python3.7/site-packages/DeepTCR-1.4.19-py3.7.egg/DeepTCR/functions/Layers.py:137: The name tf.sparse.placeholder is deprecated. Please use tf.compat.v1.sparse.placeholder instead.
#
# WARNING:tensorflow:From /Users/zhangzhiwen/opt/anaconda3/lib/python3.7/site-packages/DeepTCR-1.4.19-py3.7.egg/DeepTCR/functions/Layers.py:12: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From